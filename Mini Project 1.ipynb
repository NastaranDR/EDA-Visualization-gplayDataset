# %% [markdown]
# <img src = "https://www.cyclonis.com/images/2020/03/googleplay.jpg" width=50%>

# %% [markdown]
# ## Importing the libraries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load and Prepare Data

# %%
df=pd.read_csv('googleplaystore.csv')

# %% [markdown]
# ## EDA

# %% [markdown]
# ### view all of Data Frame

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Get the first 5 Samples of the dataframe

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### Get the Last 5 Samples of the dataframe

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Receive 5  random samples

# %%
df.sample(5)
# Out:
#                                                  App            Category  \
# 3554                          To-Do Calendar Planner        PRODUCTIVITY
# 4057                                  Mind Games Pro              FAMILY
# 503                 Once - Quality Matches Every day              DATING
# 9588                              Shoot Em Down Free              FAMILY
# 1297  Keep Trainer - Workout Trainer & Fitness Coach  HEALTH_AND_FITNESS
#
#       Rating Reviews                Size    Installs  Type  Price  \
# 3554     4.2   30291  Varies with device  1,000,000+  Free      0
# 4057     4.6   15301                 18M    100,000+  Paid  $2.99
# 503      4.4  222888                 21M  1,000,000+  Free      0
# 9588     3.7    2850                 39M    500,000+  Free      0
# 1297     4.7   14810  Varies with device  1,000,000+  Free      0
#
#      Content Rating              Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Receive number of rows and columns

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Receive more info about df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Get a list of column names in data frame

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# #### Get the type of values ​​in each column

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### Receive number of values in all df

# %%
df.size
# Out:
# 140933

# %% [markdown]
# #### Rename columns whose names contain spaces. To work better with columns

# %%
df = df.rename(columns = {"Content Rating" : "Content" , "Last Updated":"LastUpdated" ,"Current Ver" : "CurrentVer" , "Android Ver" :"AndroidVer" })

# %% [markdown]
# #### receive list of name of columns again

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content', 'Genres', 'LastUpdated', 'CurrentVer',
#        'AndroidVer'],
#       dtype='object')

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Grouping the values ​​in column Category. How many of each group are there in this column?

# %%
df["Category"].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %% [markdown]
# #### result :
# - Most of the values ​​in this column belong to the Family & Games category.
# - Most of the apps are in the Family & Games category. The Beauty category has the least number of apps.

# %% [markdown]
# #### Grouping the values ​​in column Type. How many of each group are there in this column?

# %%
df.Type.value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# #### result :
# - Most of the values ​​in this column belong to Free Type.
# - Most of the apps are in Free Type.

# %% [markdown]
# #### Grouping the values ​​in column Content. How **Percent** of each group are there in this column?

# %%
df.Content.value_counts(normalize = True) * 100
# Out:
# Content
# Everyone           80.387454
# Teen               11.143911
# Mature 17+          4.603321
# Everyone 10+        3.819188
# Adults only 18+     0.027675
# Unrated             0.018450
# Name: proportion, dtype: float64

# %% [markdown]
# ### Result :
# - Above we can easily understand that 80% of the content is for everyone. Or for example 11% of it is for Teen.

# %% [markdown]
# #### Show all rows for only two columns: app and Installs
# #### How many installs does each app have?

# %%
df.iloc[: , [0 , 5]]
# Out:
#                                                      App     Installs
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      10,000+
# 1                                    Coloring book moana     500,000+
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...   5,000,000+
# 3                                  Sketch - Draw & Paint  50,000,000+
# 4                  Pixel Draw - Number Art Coloring Book     100,000+
# ...                                                  ...          ...
# 10836                                   Sya9a Maroc - FR       5,000+
# 10837                   Fr. Mike Schmitz Audio Teachings         100+
# 10838                             Parkinson Exercices FR       1,000+
# 10839                      The SCP Foundation DB fr nn5n       1,000+
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  10,000,000+
#
# [10841 rows x 2 columns]

# %% [markdown]
# #### Show  rows in range 0 to 20 for only two columns: Rating , Price

# %%
df.iloc[:20 , [2,7]]
# Out:
#     Rating Price
# 0      4.1     0
# 1      3.9     0
# 2      4.7     0
# 3      4.5     0
# 4      4.3     0
# 5      4.4     0
# 6      3.8     0
# 7      4.1     0
# 8      4.4     0
# 9      4.7     0
# 10     4.4     0
# 11     4.4     0
# 12     4.2     0
# 13     4.6     0
# 14     4.4     0
# 15     3.2     0
# 16     4.7     0
# 17     4.5     0
# 18     4.3     0
# 19     4.6     0

# %% [markdown]
# #### What is the range of values ​​in column Rating?

# %%
df.Rating.unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %% [markdown]
# #### What is the range of values ​​in column Category?

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# #### What is the range of values ​​in column Reviews?

# %%
df.Reviews.unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %% [markdown]
# #### What is the range of values ​​in column Size?

# %%
df.Size.unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# #### What is the range of values ​​in Type column?

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %% [markdown]
# #### What is the range of values ​​in Content column?

# %%
df.Content.unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %% [markdown]
# #### What is the range of values ​​in column Installs?

# %%
df.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %% [markdown]
# #### What is the range of values ​​in column Price?

# %%
df.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %% [markdown]
# #### Sorting df by Rating values ​​in ascending order

# %%
df.sort_values("Rating")
# Out:
#                                                     App             Category  \
# 8820                                     DS Creator 2.0                TOOLS
# 7144                                      CB Mobile Biz              FINANCE
# 10400           Familial Hypercholesterolaemia Handbook              MEDICAL
# 10591  Lottery Ticket Checker - Florida Results & Lotto                TOOLS
# 5151                                      Clarksburg AH              MEDICAL
# ...                                                 ...                  ...
# 10824                                         Cardio-FR              MEDICAL
# 10825                                Naruto & Boruto FR               SOCIAL
# 10831                          payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10835                                          FR Forms             BUSINESS
# 10838                            Parkinson Exercices FR              MEDICAL
#
# ...

# %% [markdown]
# #### Sorting df by Rating values ​​in descending order

# %%
df.sort_values("Rating" , ascending = False)
# Out:
#                                            App             Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                  1.9    19.0
# 9511                  Ek Bander Ne Kholi Dukan               FAMILY     5.0
# 10166                     FA Player Essentials               SPORTS     5.0
# 7895                Dine In CT - Food Delivery             SHOPPING     5.0
# 5118                          Eternal Light AG               SOCIAL     5.0
# ...                                        ...                  ...     ...
# 10824                                Cardio-FR              MEDICAL     NaN
# 10825                       Naruto & Boruto FR               SOCIAL     NaN
# 10831                 payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                                 FR Forms             BUSINESS     NaN
# 10838                   Parkinson Exercices FR              MEDICAL     NaN
#
# ...

# %% [markdown]
# #### How many free apps and how many paid apps does each category have?

# %%
pd.crosstab( df.Category , df.Type) # To har daste che tedad az har type vojud dare
# Out:
# Type                 0  Free  Paid
# Category
# 1.9                  1     0     0
# ART_AND_DESIGN       0    62     3
# AUTO_AND_VEHICLES    0    82     3
# BEAUTY               0    53     0
# BOOKS_AND_REFERENCE  0   203    28
# BUSINESS             0   446    14
# COMICS               0    60     0
# COMMUNICATION        0   360    27
# DATING               0   227     7
# EDUCATION            0   152     4
# ENTERTAINMENT        0   147     2
# EVENTS               0    63     1
# FAMILY               0  1780   191
# FINANCE              0   349    17
# FOOD_AND_DRINK       0   125     2
# GAME                 0  1061    83
# HEALTH_AND_FITNESS   0   325    16
# HOUSE_AND_HOME       0    88     0
# LIBRARIES_AND_DEMO   0    84     1
# LIFESTYLE            0   363    19
# MAPS_AND_NAVIGATION  0   132     5
# MEDICAL              0   354   109
# NEWS_AND_MAGAZINES   0   281     2
# PARENTING            0    58     2
# PERSONALIZATION      0   309    83
# ...

# %% [markdown]
# #### What percentage of each category is free and what percentage is paid?
# #### har daste chand % free & chand % paid dare?

# %%
pd.crosstab(df.Category , df.Type , normalize='index') * 100

# %% [markdown]
# #### What percentage of each category is there in each type?
# #### Free app ha che % az har category darand.

# %%
pd.crosstab(df.Category , df.Type , normalize = 'columns') * 100
# Out:
# Type                     0       Free    Paid
# Category
# 1.9                  100.0   0.000000   0.000
# ART_AND_DESIGN         0.0   0.617591   0.375
# AUTO_AND_VEHICLES      0.0   0.816814   0.375
# BEAUTY                 0.0   0.527941   0.000
# BOOKS_AND_REFERENCE    0.0   2.022114   3.500
# BUSINESS               0.0   4.442674   1.750
# COMICS                 0.0   0.597669   0.000
# COMMUNICATION          0.0   3.586015   3.375
# DATING                 0.0   2.261181   0.875
# EDUCATION              0.0   1.514095   0.500
# ENTERTAINMENT          0.0   1.464289   0.250
# EVENTS                 0.0   0.627553   0.125
# FAMILY                 0.0  17.730850  23.875
# FINANCE                0.0   3.476442   2.125
# FOOD_AND_DRINK         0.0   1.245144   0.250
# GAME                   0.0  10.568782  10.375
# HEALTH_AND_FITNESS     0.0   3.237374   2.000
# HOUSE_AND_HOME         0.0   0.876581   0.000
# LIBRARIES_AND_DEMO     0.0   0.836737   0.125
# ...

# %% [markdown]
# # Result :
# - The family category has the most free apps.

# %% [markdown]
# ####  How many free apps have been installed more than 1000 times? How many paid apps have been installed more than 1000 times?

# %%
pd.crosstab(df.Installs , df.Type)
# Out:
# Type            0  Free  Paid
# Installs
# 0+              0     4    10
# 1+              0    46    21
# 1,000+          0   758   149
# 1,000,000+      0  1555    24
# 1,000,000,000+  0    58     0
# 10+             0   316    70
# 10,000+         0   925   129
# 10,000,000+     0  1249     3
# 100+            0   623    96
# 100,000+        0  1079    90
# 100,000,000+    0   409     0
# 5+              0    70    12
# 5,000+          0   410    67
# 5,000,000+      0   752     0
# 50+             0   171    34
# 50,000+         0   436    43
# 50,000,000+     0   289     0
# 500+            0   290    40
# 500,000+        0   527    12
# 500,000,000+    0    72     0
# Free            1     0     0

# %% [markdown]
# # Result :
# - The number of installs of free apps is more than paid apps.

# %% [markdown]
# #### How many apps with Teen content have had over 1,000 installs?

# %%
pd.crosstab(df.Installs , df.Content )
# Out:
# Content         Adults only 18+  Everyone  Everyone 10+  Mature 17+  Teen  \
# Installs
# 0                             0         0             1           0     0
# 0+                            0        12             0           0     2
# 1+                            0        61             0           3     3
# 1,000+                        0       802            15          27    63
# 1,000,000+                    1      1217            73          84   204
# 1,000,000,000+                0        34             6           0    18
# 10+                           0       333             4          12    37
# 10,000+                       0       908            28          39    79
# 10,000,000+                   0       910            86          75   181
# 100+                          0       623             6          24    66
# 100,000+                      0       944            42          71   112
# ...

# %% [markdown]
# #### Result :
# - The number of app installs with EVERYBODY content is more than other content.

# %% [markdown]
# #### What is the average of Rating in each category of applications?

# %%
df.groupby('Category')['Rating'].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %% [markdown]
# #### What is the min of Rating in each category of applications?

# %%
df.groupby('Category')['Rating'].min()
# Out:
# Category
# 1.9                    19.0
# ART_AND_DESIGN          3.2
# AUTO_AND_VEHICLES       2.1
# BEAUTY                  3.1
# BOOKS_AND_REFERENCE     2.7
# BUSINESS                1.0
# COMICS                  2.8
# COMMUNICATION           1.0
# DATING                  1.0
# EDUCATION               3.5
# ENTERTAINMENT           3.0
# EVENTS                  2.9
# FAMILY                  1.0
# FINANCE                 1.0
# FOOD_AND_DRINK          1.7
# GAME                    1.0
# HEALTH_AND_FITNESS      1.4
# HOUSE_AND_HOME          2.8
# LIBRARIES_AND_DEMO      3.1
# LIFESTYLE               1.5
# MAPS_AND_NAVIGATION     1.9
# MEDICAL                 1.0
# NEWS_AND_MAGAZINES      1.7
# PARENTING               2.0
# PERSONALIZATION         2.5
# PHOTOGRAPHY             2.0
# PRODUCTIVITY            1.0
# SHOPPING                1.6
# SOCIAL                  1.9
# SPORTS                  1.5
# TOOLS                   1.0
# TRAVEL_AND_LOCAL        2.2
# ...

# %% [markdown]
# #### What is the max of Rating in each category of applications?

# %%
df.groupby('Category')['Rating'].max()
# Out:
# Category
# 1.9                    19.0
# ART_AND_DESIGN          5.0
# AUTO_AND_VEHICLES       4.9
# BEAUTY                  4.9
# BOOKS_AND_REFERENCE     5.0
# BUSINESS                5.0
# COMICS                  5.0
# COMMUNICATION           5.0
# DATING                  5.0
# EDUCATION               4.9
# ENTERTAINMENT           4.7
# EVENTS                  5.0
# FAMILY                  5.0
# FINANCE                 5.0
# FOOD_AND_DRINK          5.0
# GAME                    5.0
# HEALTH_AND_FITNESS      5.0
# HOUSE_AND_HOME          4.8
# LIBRARIES_AND_DEMO      5.0
# LIFESTYLE               5.0
# MAPS_AND_NAVIGATION     4.9
# MEDICAL                 5.0
# NEWS_AND_MAGAZINES      5.0
# PARENTING               5.0
# PERSONALIZATION         5.0
# PHOTOGRAPHY             5.0
# PRODUCTIVITY            5.0
# SHOPPING                5.0
# SOCIAL                  5.0
# SPORTS                  5.0
# TOOLS                   5.0
# TRAVEL_AND_LOCAL        5.0
# ...

# %% [markdown]
# #### What is the mean of Rating in each Type of applications?

# %%
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# #### What is the max of Rating in each Type of applications?

# %%
df.groupby('Type')['Rating'].max()
# Out:
# Type
# 0       19.0
# Free     5.0
# Paid     5.0
# Name: Rating, dtype: float64

# %% [markdown]
# #### What is the min of Rating in each Type of applications?

# %%
df.groupby('Type')['Rating'].min()
# Out:
# Type
# 0       19.0
# Free     1.0
# Paid     1.0
# Name: Rating, dtype: float64

# %% [markdown]
# #### What is the mean of Rating in each Content of applications?

# %%
df.groupby('Content')['Rating'].mean()
# Out:
# Content
# Adults only 18+    4.300000
# Everyone           4.186375
# Everyone 10+       4.257179
# Mature 17+         4.123427
# Teen               4.233487
# Unrated            4.100000
# Name: Rating, dtype: float64

# %% [markdown]
# #### What is the max of Rating in each content of applications?

# %%
df.groupby('Content')['Rating'].max()
# Out:
# Content
# Adults only 18+    4.6
# Everyone           5.0
# Everyone 10+       5.0
# Mature 17+         5.0
# Teen               5.0
# Unrated            4.1
# Name: Rating, dtype: float64

# %% [markdown]
# #### What is the min of Rating in each content of applications?

# %%
df.groupby('Content')['Rating'].min()
# Out:
# Content
# Adults only 18+    3.8
# Everyone           1.0
# Everyone 10+       1.8
# Mature 17+         1.0
# Teen               2.0
# Unrated            4.1
# Name: Rating, dtype: float64

# %% [markdown]
# #### len & List of apps with Rating smaller than 4

# %%
apps = df[df.Rating <= 4] 
apps.head()
# Out:
#                                         App        Category  Rating Reviews  \
# 1                       Coloring book moana  ART_AND_DESIGN     3.9     967
# 6   Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8     178
# 15          Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2      55
# 20              Logo Maker - Small Business  ART_AND_DESIGN     4.0     450
# 28                    Pencil Sketch Drawing  ART_AND_DESIGN     3.9     136
#
#     Size  Installs  Type Price   Content                     Genres  \
# 1    14M  500,000+  Free     0  Everyone  Art & Design;Pretend Play
# 6    19M   50,000+  Free     0  Everyone               Art & Design
# 15  2.7M    5,000+  Free     0  Everyone               Art & Design
# 20   14M  100,000+  Free     0  Everyone               Art & Design
# 28  4.6M   10,000+  Free     0  Everyone               Art & Design
#
#          LastUpdated CurrentVer    AndroidVer
# 1   January 15, 2018      2.0.0  4.0.3 and up
# ...

# %%
len(apps)
# Out:
# 2566

# %% [markdown]
# #### len and List of apps with Rating greater than 4

# %%
apps1= df[df.Rating >=4]
apps1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
len(apps1)
# Out:
# 7369

# %% [markdown]
# #### len and list of  apps with Rating greater than or equal 4 and type free

# %%
apps2=df[(df.Rating>=4) & (df.Type == 'Free')]
apps2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
len(apps2)
# Out:
# 6842

# %% [markdown]
# #### len and list of  apps with Rating smaller than or equal 4 and type free

# %%
apps3 = df[(df.Rating <=4) & (df.Type == 'Free')]
apps3
# Out:
#                                              App            Category  Rating  \
# 1                            Coloring book moana      ART_AND_DESIGN     3.9
# 6        Smoke Effect Photo Maker - Smoke Editor      ART_AND_DESIGN     3.8
# 15               Learn To Draw Kawaii Characters      ART_AND_DESIGN     3.2
# 20                   Logo Maker - Small Business      ART_AND_DESIGN     4.0
# 28                         Pencil Sketch Drawing      ART_AND_DESIGN     3.9
# ...                                          ...                 ...     ...
# 10826  Frim: get new friends on local chat rooms              SOCIAL     4.0
# 10828                    Manga-FR - Anime Vostfr              COMICS     3.4
# 10830                          News Minecraft.fr  NEWS_AND_MAGAZINES     3.8
# 10832                                   FR Tides             WEATHER     3.8
# 10834                              FR Calculator              FAMILY     4.0
#
# ...

# %%
len(apps3)
# Out:
# 2423

# %% [markdown]
# ### len and list of  apps with Rating smaller than or equal 4 and type Paid

# %%
apps4 = df[(df.Rating <= 4) & (df.Type == 'Paid')]
apps4
# Out:
#                                                      App       Category  \
# 427                                   Puffin Browser Pro  COMMUNICATION
# 477                                           Calculator         DATING
# 481    AMBW Dating App: Asian Men Black Women Interra...         DATING
# 2087                                  Pinkalicious Party         FAMILY
# 2175                        Whoowasit? - Best kids game!         FAMILY
# ...                                                  ...            ...
# 10448                     Portable Wi-Fi hotspot Premium  COMMUNICATION
# 10540                       Ray Financial Calculator Pro        FINANCE
# 10583                            Florida Tides & Weather        WEATHER
# 10645                       Football Manager Mobile 2018         SPORTS
# 10782                            Trine 2: Complete Story           GAME
#
#        Rating Reviews                Size  Installs  Type   Price     Content  \
# ...

# %%
len(apps4)
# Out:
# 143

# %% [markdown]
# #### len of free apps

# %%
len(df[df.Type == 'Free'])
# Out:
# 10039

# %% [markdown]
# #### len of Paid apps

# %%
len(df[df.Type == 'Paid'])
# Out:
# 800

# %% [markdown]
# #### list and len of apps with Teen conetent and Rating greater or equal than 4 and free type

# %%
apps5 = df[(df.Content == 'Teen') & (df.Type == 'Free') & (df.Rating >=4) ]
apps5
# Out:
#                                                  App           Category  \
# 3                              Sketch - Draw & Paint     ART_AND_DESIGN
# 12                    Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 34                                   I Creative Idea     ART_AND_DESIGN
# 72     Android Auto - Maps, Media, Messaging & Voice  AUTO_AND_VEHICLES
# 112    Selfie Camera Photo Editor & Filter & Sticker             BEAUTY
# ...                                              ...                ...
# 10802                            FR: My Famous Lover             FAMILY
# 10803                   Fatal Raid - No.1 Mobile FPS               GAME
# 10804                                   Poker Pro.Fr               GAME
# 10814                           FR: My Secret Pets!              FAMILY
# 10820                                Fr. Daoud Lamei             FAMILY
#
#        Rating Reviews  Size     Installs  Type Price Content           Genres  \
# ...

# %%
len(apps5)
# Out:
# 840

# %% [markdown]
# #### list and len of apps with Type Free and 10,000,000+ Installs and Category BeAUTY

# %%
apps6 = df[(df.Type == 'Free') & (df.Installs == '10,000,000+')&(df.Category == 'BEAUTY')]
apps6
# Out:
#                                App Category  Rating Reviews  \
# 117  Beauty Camera - Selfie Camera   BEAUTY     4.0  113715
#
#                    Size     Installs  Type Price   Content  Genres  \
# 117  Varies with device  10,000,000+  Free     0  Everyone  Beauty
#
#         LastUpdated          CurrentVer          AndroidVer
# 117  August 3, 2017  Varies with device  Varies with device

# %%
len(apps6)
# Out:
# 1

# %% [markdown]
# #### list and len of info apps with Content everyone and Type paid and installs 10,000+

# %%
apps7 = df[(df.Type == 'Paid')&(df.Content == 'Everyone')&(df.Installs == '10,000+')]
apps7
# Out:
#                                   App            Category  Rating Reviews  \
# 1227        My CookBook Pro (Ad Free)      FOOD_AND_DRINK     4.6    2129
# 1335                Meditation Studio  HEALTH_AND_FITNESS     4.6    1026
# 2152                    LEGO® Friends              FAMILY     4.4     854
# 2153          My Little Work – Garage              FAMILY     4.3     560
# 2177     Tsuro - The Game of the Path              FAMILY     4.7    2195
# ...                               ...                 ...     ...     ...
# 10442                        FiSwitch               TOOLS     4.8     615
# 10446         Smart Wi-Fi Hotspot PRO       COMMUNICATION     3.7     197
# 10448  Portable Wi-Fi hotspot Premium       COMMUNICATION     3.7     481
# 10540    Ray Financial Calculator Pro             FINANCE     4.0      67
# 10785                    sugar, sugar              FAMILY     4.2    1405
#
#                      Size Installs  Type  Price   Content  \
# ...

# %%
len(apps7)
# Out:
# 110

# %% [markdown]
# #### search for Portable Wi-Fi hotspot Premium app in dataframe

# %%
df[df.App.str.contains('Portable Wi-Fi hotspot Premium')]
# Out:
#                                   App       Category  Rating Reviews  Size  \
# 10448  Portable Wi-Fi hotspot Premium  COMMUNICATION     3.7     481  420k
#
#       Installs  Type  Price   Content         Genres        LastUpdated  \
# 10448  10,000+  Paid  $0.99  Everyone  Communication  December 16, 2015
#
#       CurrentVer  AndroidVer
# 10448    1.4.0.2  2.3 and up

# %% [markdown]
# #### search for an app with content = Teen and Genres Communication in dataframe

# %%
df.query(' Content == "Teen" & Genres == "Communication" ')
# Out:
#                                                App       Category  Rating  \
# 337                              Messenger for SMS  COMMUNICATION     4.3
# 363                                            Who  COMMUNICATION     4.3
# 366    UC Browser Mini -Tiny Fast Private & Secure  COMMUNICATION     4.4
# 377                                     Omlet Chat  COMMUNICATION     3.9
# 378    UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 393                                            Who  COMMUNICATION     4.3
# 419    UC Browser Mini -Tiny Fast Private & Secure  COMMUNICATION     4.4
# 420    UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 3899                 LokLok: Draw on a Lock Screen  COMMUNICATION     4.1
# 3971   UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 4033                     Discord - Chat for Gamers  COMMUNICATION     4.5
# 4279                                           Kik  COMMUNICATION     4.3
# ...

# %% [markdown]
# #### search for an app with Type = Free and Category FAMILY  and Install =10,000,000+ in dataframe

# %%
df.query(' Type == "Free" & Category == "FAMILY" & Installs == "500,000+" ')
# Out:
#                                   App Category  Rating Reviews  \
# 2028   Happy Fruits Bomb - Cube Blast   FAMILY     4.5    2150
# 2030      Princess Adventures Puzzles   FAMILY     4.4     382
# 2033              Coloring book moana   FAMILY     3.9     974
# 2035     Kids Educational :All in One   FAMILY     4.5    1455
# 2044              Garden Fruit Legend   FAMILY     4.6    4289
# ...                               ...      ...     ...     ...
# 10391       Police VAZ LADA Simulator   FAMILY     3.6    3502
# 10392               Scary Video Maker   FAMILY     3.7    9296
# 10438  Dolphin and fish coloring book   FAMILY     3.9    2249
# 10480  FJ 4x4 Cruiser Offroad Driving   FAMILY     4.1    3543
# 10481     FJ 4x4 Cruiser Snow Driving   FAMILY     4.2    1619
#
#                      Size  Installs  Type Price   Content  \
# 2028                  20M  500,000+  Free     0  Everyone
# 2030                  44M  500,000+  Free     0  Everyone
# ...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Identify missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   App          10841 non-null  object
#  1   Category     10841 non-null  object
#  2   Rating       9367 non-null   float64
#  3   Reviews      10841 non-null  object
#  4   Size         10841 non-null  object
#  5   Installs     10841 non-null  object
#  6   Type         10840 non-null  object
#  7   Price        10841 non-null  object
#  8   Content      10840 non-null  object
#  9   Genres       10841 non-null  object
#  10  LastUpdated  10841 non-null  object
#  11  CurrentVer   10833 non-null  object
#  12  AndroidVer   10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Number of missing values ​​in each column

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating         1474
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content           1
# Genres            0
# LastUpdated       0
# CurrentVer        8
# AndroidVer        3
# dtype: int64

# %% [markdown]
# #### Missing percentage in each column

# %%
(df.isnull().mean() * 100)
# Out:
# App             0.000000
# Category        0.000000
# Rating         13.596532
# Reviews         0.000000
# Size            0.000000
# Installs        0.000000
# Type            0.009224
# Price           0.000000
# Content         0.009224
# Genres          0.000000
# LastUpdated     0.000000
# CurrentVer      0.073794
# AndroidVer      0.027673
# dtype: float64

# %% [markdown]
# ## Strorytelling - Visualization

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
# %matplotlib inline

# %% [markdown]
# #### Visualization distribution of Installs data

# %%
sns.displot(df , x = 'Installs' )
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### result =
# - we can see that number of apps with +1,000,000 installations have the more than enother.

# %%
sns.displot(df , x = 'Installs' , hue = 'Type' , palette = 'Paired')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### result :
# - Most of the apps were installed over 1,000,000 times, and a large portion of that is for free apps.
# - The number of installs for free apps is higher than paid apps.
# - people install free apps more

# %% [markdown]
# ####  Visualization  distribution of free and paid types

# %%
sns.displot(df , x = 'Type' , shrink = 0.8 )
plt.show()

# %% [markdown]
# #### result :
# - most apps have Free type
# -  paid apps are less that free apps

# %% [markdown]
# #### Visualization distribution for each content

# %%
sns.displot(df  , x = 'Content')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Visualization  distribution of  Categorys data

# %%
sns.displot(df , x = 'Category' )
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### result =
# - Most of the programs are from categories FAMILY and Game,
# -  number of programs with category ART_AND_DESIGN  and BEUTY and PARENTING are less than the rest of the categories.

# %%
lastupdate = df['LastUpdated'][0: 30]
sns.displot(df , x =lastupdate)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### result =  in range 40 first of data , last update of most apps is for 12 July 2018

# %% [markdown]
# result = content of most apps is for everybody , after it for teen ,

# %% [markdown]
# #### Visualization  distribution for each Rating With a kde-type graph that displays a continuous distribution

# %%
sns.displot(df ,  x = 'Rating' , kind = 'kde')
plt.show()

# %% [markdown]
# #### result =
# Most of the apps have  rating close to 5

# %% [markdown]
# #### Visualization  distribution for each Rating And separately for each type

# %%
sns.displot(df , x = 'Rating' , hue = 'Type' , kind = 'kde' )
plt.show()

# %% [markdown]
# result = There are more free apps with a rating of 4 than paid apps with the same rating.

# %%
sns.displot(df , x = 'Rating' , hue = 'Type' , kind = 'kde' , fill = True )
plt.show()

# %%
sns.set_theme(style = 'ticks' , color_codes=True)

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %% [markdown]
# #### scatterplot for two features Type and rating

# %%
sns.catplot(data = df , y = 'Rating' , x = 'Type' , palette = 'Paired' )
plt.show()

# %%
sns.catplot(data = df , x = 'Content' , y = 'Rating' , palette = 'Paired'  )
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# result = For apps with Everybody content, most ratings are specified.

# %%
sns.catplot(data = df , x = 'Content' , y = 'Installs' , palette='Paired')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.catplot(data =  df , x = 'Content' , y = 'Rating' , kind = 'boxen' , palette = 'Paired')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# result = Lowest ratings for apps with everybody content is 1 and highest rating is 5.
# Lowest ratings for apps with Teen content is 2 and highest rating is 5.
# Lowest ratings for apps with everybody +10 content is 1.8 and highest rating is 5.
# Lowest ratings for apps with Adult only content is 3.5 and highest rating is 4.5

# %%
sns.catplot(data =  df , x = 'Content' , y = 'Rating' , kind = 'violin' , palette = 'Paired')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# result = Lowest ratings for apps with everybody content is 1 and highest rating is 5.
# Lowest ratings for apps with Teen content is 1.9 and highest rating is 5.
# Lowest ratings for apps with everybody +10 content is 1.5 and highest rating is 5.
# Lowest ratings for apps with Adult only content is 3.5 and highest rating is 4.5

# %%
sns.catplot(data = df , x = 'Content' , y = 'Rating' , kind = 'bar' , palette = 'Paired' , hue = 'Type')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# result =
# - Teen Content with Paid type has received higher ratings.
# - Everybody Content with paid type has received higher ratings than Free type of this content.
# - in every content , paid type has received higher ratings than free type
# - app with paid types has received higher ratings.

# %%
sns.catplot(data = df , x = 'Content' , y = 'Rating' , kind = 'point' , palette = 'Paired' , hue = 'Type')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# result :
# - The highest average rating belongs to the Teen Content and its paid type.
# - Adult programs have been completely free.
# - The average rating of the Paid type is higher in all Contents.

# %%
sns.catplot(x = 'Content' , kind = 'count' , palette = 'Paired' , data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.catplot(x = 'Content' , kind = 'count' ,hue = 'Type', palette = 'ch:.25' , data=df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# result : number of free apps in ech content is more than paid apps in same content
